# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt

# %%
global_info_long = pd.read_csv("global_info_2010_2020.csv")
global_info_long.rename(columns = {"Country Name": "Country", "2010 [YR2010]":"Yr2010", "2020 [YR2020]":"Yr2020"}, inplace = True)
global_info_long.dropna(inplace = True)

# %%
global_info_long.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10093    False
# 10094    False
# 10095    False
# 10096    False
# 10097    False
# Length: 10098, dtype: bool

# %%
global_2010 = global_info_long.pivot(index = "Country", columns = "Series Name", values = "Yr2010")
global_2010['Year'] = 2010
global_2020 = global_info_long.pivot(index = "Country", columns = "Series Name", values = "Yr2020")
global_2020['Year'] = 2020

# %%
global_2010.head()
global_2010.describe(include = "all")
# Out:
# Series Name Access to electricity (% of population)  \
# count                                           198
# unique                                          114
# top                                             100
# freq                                             58
# mean                                            NaN
# std                                             NaN
# min                                             NaN
# 25%                                             NaN
# 50%                                             NaN
# 75%                                             NaN
# max                                             NaN
#
# Series Name Adjusted savings: net forest depletion (% of GNI)  \
# count                                                     198
# unique                                                    103
# top                                                         0
# freq                                                       78
# mean                                                      NaN
# std                                                       NaN
# min                                                       NaN
# 25%                                                       NaN
# 50%                                                       NaN
# 75%                                                       NaN
# max                                                       NaN
#
# Series Name Agricultural land (% of land area)  \
# count                                      198
# unique                                     195
# top                                         ..
# freq                                         4
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
# Series Name Arms imports (SIPRI trend indicator values)  \
# count                                               198
# unique                                               91
# top                                                  ..
# freq                                                 79
# mean                                                NaN
# std                                                 NaN
# min                                                 NaN
# 25%                                                 NaN
# 50%                                                 NaN
# 75%                                                 NaN
# max                                                 NaN
#
# Series Name Average precipitation in depth (mm per year)  \
# count                                                198
# unique                                               173
# top                                                   ..
# freq                                                  20
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
# Series Name Current health expenditure (% of GDP) Forcibly displaced people  \
# count                                         198                       198
# unique                                        190                       159
# top                                            ..                        ..
# freq                                            9                        35
# mean                                          NaN                       NaN
# std                                           NaN                       NaN
# min                                           NaN                       NaN
# 25%                                           NaN                       NaN
# 50%                                           NaN                       NaN
# 75%                                           NaN                       NaN
# max                                           NaN                       NaN
#
# Series Name Forest area (% of land area) Government Effectiveness: Estimate  \
# count                                198                                198
# unique                               194                                193
# top                                    0                                 ..
# freq                                   3                                  5
# mean                                 NaN                                NaN
# std                                  NaN                                NaN
# min                                  NaN                                NaN
# 25%                                  NaN                                NaN
# 50%                                  NaN                                NaN
# 75%                                  NaN                                NaN
# max                                  NaN                                NaN
#
# Series Name Gross national expenditure (% of GDP)  ...  \
# count                                         198  ...
# unique                                        164  ...
# top                                            ..  ...
# freq                                           35  ...
# mean                                          NaN  ...
# std                                           NaN  ...
# min                                           NaN  ...
# 25%                                           NaN  ...
# 50%                                           NaN  ...
# 75%                                           NaN  ...
# max                                           NaN  ...
#
# Series Name Taxes on income, profits and capital gains (% of revenue)  \
# count                                                      198
# unique                                                     124
# top                                                         ..
# freq                                                        74
# mean                                                       NaN
# std                                                        NaN
# min                                                        NaN
# 25%                                                        NaN
# 50%                                                        NaN
# 75%                                                        NaN
# max                                                        NaN
#
# Series Name Taxes on international trade (% of revenue)  \
# count                                               198
# unique                                              107
# top                                                  ..
# freq                                                 92
# mean                                                NaN
# std                                                 NaN
# min                                                 NaN
# 25%                                                 NaN
# 50%                                                 NaN
# 75%                                                 NaN
# max                                                 NaN
#
# Series Name Unemployment, total (% of total labor force) (modeled ILO estimate)  \
# count                                                      198
# unique                                                     181
# top                                                         ..
# freq                                                        17
# mean                                                       NaN
# std                                                        NaN
# min                                                        NaN
# 25%                                                        NaN
# 50%                                                        NaN
# 75%                                                        NaN
# max                                                        NaN
#
# Series Name Unemployment, total (% of total labor force) (national estimate)  \
# count                                                      198
# unique                                                     127
# top                                                         ..
# freq                                                        71
# mean                                                       NaN
# std                                                        NaN
# min                                                        NaN
# 25%                                                        NaN
# 50%                                                        NaN
# 75%                                                        NaN
# max                                                        NaN
#
# Series Name Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate)  \
# count                                                      198
# unique                                                     182
# top                                                         ..
# freq                                                        17
# mean                                                       NaN
# std                                                        NaN
# min                                                        NaN
# 25%                                                        NaN
# 50%                                                        NaN
# 75%                                                        NaN
# max                                                        NaN
#
# Series Name Unemployment, youth total (% of total labor force ages 15-24) (national estimate)  \
# count                                                      198
# unique                                                     115
# top                                                         ..
# freq                                                        84
# mean                                                       NaN
# std                                                        NaN
# min                                                        NaN
# 25%                                                        NaN
# 50%                                                        NaN
# 75%                                                        NaN
# max                                                        NaN
#
# Series Name Urban population (% of total population)  \
# count                                            198
# unique                                           193
# top                                              100
# freq                                               5
# mean                                             NaN
# std                                              NaN
# min                                              NaN
# 25%                                              NaN
# 50%                                              NaN
# 75%                                              NaN
# max                                              NaN
#
# Series Name Urban population growth (annual %)  \
# count                                      198
# unique                                     198
# top                           3.81906849382784
# freq                                         1
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
# Series Name Wage and salaried workers, total (% of total employment) (modeled ILO estimate)  \
# count                                                      198
# unique                                                     182
# top                                                         ..
# freq                                                        17
# mean                                                       NaN
# std                                                        NaN
# min                                                        NaN
# 25%                                                        NaN
# 50%                                                        NaN
# 75%                                                        NaN
# max                                                        NaN
#
# Series Name    Year
# count         198.0
# unique          NaN
# top             NaN
# freq            NaN
# mean         2010.0
# std             0.0
# min          2010.0
# 25%          2010.0
# 50%          2010.0
# 75%          2010.0
# max          2010.0
#
# [11 rows x 52 columns]

# %%
global_2010.value_counts()
# Out:
# Access to electricity (% of population)  Adjusted savings: net forest depletion (% of GNI)  Agricultural land (% of land area)  Arms imports (SIPRI trend indicator values)  Average precipitation in depth (mm per year)  Current health expenditure (% of GDP)  Forcibly displaced people  Forest area (% of land area)  Government Effectiveness: Estimate  Gross national expenditure (% of GDP)  Imports of goods and services (% of GDP)  Inflation, consumer prices (annual %)  Intentional homicides (per 100,000 people)  International migrant stock (% of population)  International tourism, number of arrivals  Labor force, female (% of total labor force)  Labor force, total  Land area (sq. km)  Life expectancy at birth, female (years)  Life expectancy at birth, male (years)  Life expectancy at birth, total (years)  Manufactures exports (% of merchandise exports)  Manufactures imports (% of merchandise imports)  Manufacturing, value added (% of GDP)  Military expenditure (current LCU)  Military expenditure (current USD)  Mortality rate, adult, female (per 1,000 female adults)  Mortality rate, adult, male (per 1,000 male adults)  Net migration  Net official aid received (constant 2021 US$)  Net primary income (BoP, current US$)  Physicians (per 1,000 people)  Political Stability and Absence of Violence/Terrorism: Number of Sources  Population growth (annual %)  Population in largest city  Refugees under the mandate of the UNHCR by country or territory of asylum  Rural population (% of total population)  Sex ratio at birth (male births per female births)  Share of youth not in education, employment or training, total (% of youth population)  (modeled ILO estimate)  Suicide mortality rate (per 100,000 population)  Tax revenue (% of GDP)  Taxes on goods and services (% of revenue)  Taxes on income, profits and capital gains (% of revenue)  Taxes on international trade (% of revenue)  Unemployment, total (% of total labor force) (modeled ILO estimate)  Unemployment, total (% of total labor force) (national estimate)  Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate)  Unemployment, youth total (% of total labor force ages 15-24) (national estimate)  Urban population (% of total population)  Urban population growth (annual %)  Wage and salaried workers, total (% of total employment) (modeled ILO estimate)  Year
# ..                                       ..                                                 ..                                  ..                                           ..                                            ..                                     ..                         ..                            -0.583555221557617                  138.839168541723                       60.5083118539118                          3.48050763735842                       5.91332240856316                            ..                                             ..                                         ..                                            ..                  ..                  76.946                                    72.326                                  74.609                                   ..                                               ..                                               13.7726216140452                       29128217                            38578120.5093736                    68.002                                                   125.142                                              -29433         ..                                             89905217.5853803                       ..                             3                                                                         -0.331415173591033            ..                          ..                                                                         ..                                        1.117                                               ..                                                                                                              ..                                               ..                      ..                                          ..                                                         ..                                           ..                                                                   ..                                                                ..                                                                                    ..                                                                                 ..                                        ..                                  ..                                                                               2010    1
# 1.5                                      ..                                                 ..                                  2000000                                      ..                                            ..                                     ..                         ..                            ..                                  68.0468965280446                       29.5089655488059                          1.16962180301108                       ..                                          2.56456661006963                               ..                                         50.1160124421398                              4109904             ..                  58.546                                    56.369                                  57.485                                   ..                                               ..                                               2.33112377386204                       1501000000                          650910667.82307                     268.794                                                  306.579                                              299402         ..                                             ..                                     ..                             ..                                                                        5.29254618151503              254761                      ..                                                                         82.14                                     1.035                                               29.727                                                                                                          4.87                                             ..                      ..                                          ..                                                         ..                                           12.503                                                               ..                                                                19.442                                                                                ..                                                                                 17.86                                     6.18676907042487                    18.2230020870034                                                                 2010    1
# 100                                      ..                                                 ..                                  ..                                           ..                                            4.95791674                             ..                         0                             ..                                  ..                                     ..                                        ..                                     ..                                          57.3537793459085                               279000                                     ..                                            ..                  2.027               87.071                                    82.241                                  84.644                                   ..                                               ..                                               ..                                     ..                                  ..                                  23.9                                                     41.757                                               808            ..                                             ..                                     ..                             2                                                                         2.4388102675618               ..                          ..                                                                         0                                         1.045                                               ..                                                                                                              ..                                               ..                      ..                                          ..                                                         ..                                           ..                                                                   ..                                                                ..                                                                                    ..                                                                                 100                                       2.43881026756178                    ..                                                                               2010    1
#                                                                                             11.4285714285714                    ..                                           ..                                            ..                                     ..                         52.6571428571429              1.25646901130676                    ..                                     287.025901942646                          ..                                     52.7595108439637                            53.2834502077419                               2531000                                    50.0908482356316                              52285               350                 81.4                                      74.5                                    77.8658536585366                         ..                                               ..                                               ..                                     ..                                  ..                                  78.622                                                   198.846                                              -1251          ..                                             ..                                     ..                             2                                                                         -0.0433657352905335           ..                          ..                                                                         5.40600000000001                          1.039                                               17.088                                                                                                          ..                                               ..                      ..                                          ..                                                         ..                                           11.742                                                               ..                                                                24.195                                                                                ..                                                                                 94.594                                    0.14156495068734                    89.2786146574193                                                                 2010    1
#                                                                                             16.6666666666667                    ..                                           ..                                            6.20853519                             ..                         16.6666666666667              ..                                  ..                                     ..                                        2.58541815582587                       0                                           14.3336591723688                               1976000                                    ..                                            ..                  60                  85.327                                    81.395                                  83.464                                   ..                                               ..                                               ..                                     ..                                  ..                                  31.858                                                   52.73                                                592            ..                                             ..                                     ..                             2                                                                         0.615052590123215             ..                          ..                                                                         4.26000000000001                          1.066                                               ..                                                                                                              ..                                               15.5920229527836        24.7364535239097                            15.6087327273777                                           0.722736915673785                            ..                                                                   4.37                                                              ..                                                                                    17.25                                                                              95.74                                     0.857589516789495                   ..                                                                               2010    1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ..
# 99.7553972530963                         0.00530038049853009                                42.4037795916086                    3066000000                                   ..                                            9.89968263095373                       1628565                    39.1990406031898              ..                                  ..                                     38.0542451380323                          1.53112270420926                       ..                                          9.97698850049258                               708410742.423597                           45.2497596447687                              211014754           3995335.36          82.7565571605721                          76.674635481056                         79.6354307923887                         76.1913246477551                                 67.8470919444207                                 14.3889824945813                       ..                                  213721204010.243                    55.9480221825214                                         119.683306244134                                     656784         ..                                             ..                                     3.47718994397296               ..                                                                        0.158405309698739             ..                          1156054                                                                    27.0335710919567                          1.05509169292835                                    12.8734703732072                                                                                                13.462027975768                                  18.6018332301619        32.7374406906088                            17.6833484672873                                           ..                                           9.8727209377786                                                      9.87274925563262                                                  22.9375151466125                                                                      22.9725172502792                                                                   72.9664289080433                          0.443739433116333                   82.7975540715386                                                                 2010    1
# 99.8                                     ..                                                 21.9230769230769                    ..                                           1427                                          5.2136941                              ..                         42.3076923076923              1.25646901130676                    ..                                     ..                                        0.850878649795844                      44.3009936079995                            13.8390128361858                               624000                                     ..                                            ..                  260                 74.718                                    68.466                                  71.452                                   87.2321527867419                                 73.6494515605365                                 8.26524108934907                       ..                                  ..                                  117.403                                                  207.537                                              -449           ..                                             -57473521.0075741                      ..                             3                                                                         -0.149314248854052            ..                          ..                                                                         68.678                                    1.037                                               ..                                                                                                              ..                                               16.3117664263224        14.7640121870949                            16.7424609594208                                           27.877887010139                              ..                                                                   ..                                                                ..                                                                                    ..                                                                                 31.322                                    -0.597949732952985                  ..                                                                               2010    1
#                                          0                                                  29.0067012711524                    16000000                                     667                                           6.097435                               103                        54.1906246484645              0.722773253917694                   102.131442850983                       56.4968983568515                          -1.08463595015162                      ..                                          15.0099568576033                               5042000                                    50.3872674435627                              1058829             62227               78.4                                      68.8                                    73.4829268292683                         57.5766066935415                                 59.11063764789                                   12.1421484860866                       196000000                           259672124.197467                    98.658                                                   263.085                                              -36128         ..                                             198866026.262618                       3.101                          7                                                                         -2.08130508988111             664645                      60                                                                         32.159                                    1.051                                               17.814                                                                                                          22.72                                            14.1617549792208        38.6234214082669                            7.39723193065847                                           ..                                           19.482                                                               19.482                                                            36.24                                                                                 36.151                                                                             67.841                                    -2.04148981383623                   86.1428940022987                                                                 2010    1
#                                          0.284005045030102                                  60.9413417632596                    52000000                                     562                                           9.23538303                             11706                      11.610818405339               -0.171523153781891                  137.115348762661                       44.8945606568078                          8.17636138473952                       1.90069351554648                            7.47630501272821                               684000                                     50.0982314369723                              1510718             28470               76.4                                      70.1                                    73.1731707317073                         23.432435607047                                  55.0460223604655                                 ..                                     147600000000                        395011507.787829                    78.626                                                   208.132                                              -30009         ..                                             458281240.768841                       2.775                          6                                                                         -0.693856288987436            1065597                     3292                                                                       36.56                                     1.146                                               29.567                                                                                                          6.88                                             17.0700513990102        42.5034250540843                            18.6189207567463                                           3.60305493286515                             19.523                                                               19.523                                                            37.647                                                                                38.959                                                                             63.44                                     -0.851347120418493                  34.8793195962965                                                                 2010    1
# 99.9                                     0                                                  57.6703445605885                    162000000                                    447                                           2.64634848                             594909                     12.4914658343012              -0.813017129898071                  68.3035440951372                       20.6812669257035                          5.72687224669605                       2.23011241769356                            3.04290391106797                               1963000                                    52.3570243347329                              4281288             82656               73.101                                    67.324                                  70.309                                   2.47264472406564                                 76.3093764225872                                 4.80819498410456                       1185200000                          1476608733.57005                    100.487                                                  199.309                                              1373           ..                                             -3467078000                            3.582                          7                                                                         1.18978770786007              2061843                     1894                                                                       46.594                                    1.165                                               9.64                                                                                                            2.76                                             12.1577769928176        13.5532203730705                            10.1890492231887                                           1.45708683191714                             5.63                                                                 5.63                                                              14.64                                                                                 14.92                                                                              53.406                                    1.59505668203145                    31.9447483193235                                                                 2010    1
# Name: count, Length: 198, dtype: int64

# %%
global_2020.describe()
# Out:
# Series Name    Year
# count         198.0
# mean         2020.0
# std             0.0
# min          2020.0
# 25%          2020.0
# 50%          2020.0
# 75%          2020.0
# max          2020.0

# %% [markdown]
# Data Sources:
#
#
# *   'Happiness' Scores Datasets 2015, 2016, 2017, 2018, 2019
# *   Net Migration Information 1960-2024 Every Year
# *   Religious Composition: 2010, 2020
# *   Global Info:

# %%
happy_2015 = pd.read_csv("2015.csv")
happy_2016 = pd.read_csv("2016.csv")
happy_2017 = pd.read_csv("2017.csv")
happy_2018 = pd.read_csv("2018.csv")
happy_2019 = pd.read_csv("2019.csv")

# %%
happy_2015.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
happy_2016.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
happy_2017.columns
happy_2017.rename(columns = {"Happiness.Rank": "Happiness Rank",
                             "Happiness.Score": "Happiness Score",
                             "Economy..GDP.per.Capita.": "Economy (GDP per Capita)",
                             "Health..Life.Expectancy.": "Healthy (Life Expectancy)",
                             "Trust..Government.Corruption.": "Trust (Government Corruption)",
                             "Dystopia.Residual" : "Dystopia Residual"}, inplace= True)

# %%
happy_2018.columns
happy_2018.rename(columns = {"Overall rank": "Happiness Rank",
                             "Country or region": "Country",
                             "Score": "Happiness Score",
                             "GDP per capita": "Economy (GDP per Capita)",
                             "Freedom to make life choices": "Freedom",
                             "Perceptions of corruption": "Trust (Government Corruption)",
                             "Healthy life expectancy": "Health (Life Expectancy)"},
                  inplace = True)

# %%
happy_2019.columns
happy_2019.rename(columns = {"Overall rank": "Happiness Rank",
                             "Country or region": "Country",
                             "Score": "Happiness Score",
                             "GDP per capita": "Economy (GDP per Capita)",
                             "Freedom to make life choices": "Freedom",
                             "Perceptions of corruption": "Trust (Government Corruption)",
                             "Healthy life expectancy": "Health (Life Expectancy)"},
                  inplace = True)

# %%
happy_2017.columns
# Out:
# Index(['Country', 'Happiness Rank', 'Happiness Score', 'Whisker.high',
#        'Whisker.low', 'Economy (GDP per Capita)', 'Family',
#        'Healthy (Life Expectancy)', 'Freedom', 'Generosity',
#        'Trust (Government Corruption)', 'Dystopia Residual'],
#       dtype='object')

# %%
happy_2015.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
sns.displot(data = happy_2015, x = 'Happiness Score')
sns.displot(data = happy_2019, x = 'Happiness Score')

# %%
happy_full = happy_2015.merge(
    happy_2016, how = "left", on = "Country", suffixes = ('_2015', '_2016')).merge(
        happy_2017, how = "left", on = "Country", suffixes = ('', '_2017')).merge(
            happy_2018, how = "left", on = "Country", suffixes = ('', '_2018')).merge(
                happy_2019, how = "left", on = "Country", suffixes = ('', '_2019'))

# %%
happy_full[happy_full['Country'] == 'United States']
# Out:
#           Country    Region_2015  Happiness Rank_2015  Happiness Score_2015  \
# 14  United States  North America                   15                 7.119
#
#     Standard Error  Economy (GDP per Capita)_2015  Family_2015  \
# 14         0.03839                        1.39451      1.24711
#
#     Health (Life Expectancy)_2015  Freedom_2015  \
# 14                        0.86179       0.54604
#
#     Trust (Government Corruption)_2015  ...  Generosity_2018  \
# 14                              0.1589  ...            0.291
#
#     Trust (Government Corruption)_2018 Happiness Rank_2019  \
# 14                               0.133                19.0
#
#     Happiness Score_2019  Economy (GDP per Capita)_2019  Social support_2019  \
# 14                 6.892                          1.433                1.457
#
#     Health (Life Expectancy)_2019  Freedom_2019  Generosity_2019  \
# 14                          0.874         0.454             0.28
#
#     Trust (Government Corruption)_2019
# 14                               0.128
#
# [1 rows x 51 columns]

# %%
net_mig = pd.read_csv('netm.csv')
net_mig.head(3)

net_mig.nlargest(20, '2019')['Country Name']
net_mig_long = pd.melt(net_mig, id_vars = ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], var_name = "Year", value_name = "netMig")

# %%
# net_mig = net_mig.rename(columns=lambda x: x + '_mig' if x in [list(range(1960,2024))] else x)
net_mig.rename(columns = {"Country Name": "Country"}, inplace = True)
net_mig.drop(["Indicator Name", "Indicator Code", "Unnamed: 69"], axis = 1, inplace = True)

# %%
net_mig = net_mig.add_suffix("_NetMig").rename(columns = {"Country_NetMig": "Country", "Country Code_NetMig": "Country Code"})
net_mig.columns
# Out:
# Index(['Country', 'Country Code', '1960_NetMig', '1961_NetMig', '1962_NetMig',
#        '1963_NetMig', '1964_NetMig', '1965_NetMig', '1966_NetMig',
#        '1967_NetMig', '1968_NetMig', '1969_NetMig', '1970_NetMig',
#        '1971_NetMig', '1972_NetMig', '1973_NetMig', '1974_NetMig',
#        '1975_NetMig', '1976_NetMig', '1977_NetMig', '1978_NetMig',
#        '1979_NetMig', '1980_NetMig', '1981_NetMig', '1982_NetMig',
#        '1983_NetMig', '1984_NetMig', '1985_NetMig', '1986_NetMig',
#        '1987_NetMig', '1988_NetMig', '1989_NetMig', '1990_NetMig',
#        '1991_NetMig', '1992_NetMig', '1993_NetMig', '1994_NetMig',
#        '1995_NetMig', '1996_NetMig', '1997_NetMig', '1998_NetMig',
#        '1999_NetMig', '2000_NetMig', '2001_NetMig', '2002_NetMig',
#        '2003_NetMig', '2004_NetMig', '2005_NetMig', '2006_NetMig',
#        '2007_NetMig', '2008_NetMig', '2009_NetMig', '2010_NetMig',
#        '2011_NetMig', '2012_NetMig', '2013_NetMig', '2014_NetMig',
#        '2015_NetMig', '2016_NetMig', '2017_NetMig', '2018_NetMig',
#        '2019_NetMig', '2020_NetMig', '2021_NetMig', '2022_NetMig',
#        '2023_NetMig', '2024_NetMig'],
#       dtype='object')

# %%
rel_comp = pd.read_csv('relcomp.csv')
rel_comp[rel_comp['Country']=="United States"]
# Out:
#             Region        Country  Year   Population  Christians   Muslims  \
# 396  North America  United States  2010  311062790.0   78.278938  0.891187
# 397  North America  United States  2020  339436158.5   64.010002  1.192381
#
#      Religiously_unaffiliated  Buddhists    Hindus      Jews  Other_religions  \
# 396                 16.454805   1.152083  0.575295  1.834127         0.813565
# 397                 29.730000   1.291746  0.894286  1.689206         1.192381
#
#      Level  Countrycode
# 396      1          840
# 397      1          840

# %%
happy_full[happy_full['Country'] == "United States"]
# Out:
#           Country    Region_2015  Happiness Rank_2015  Happiness Score_2015  \
# 14  United States  North America                   15                 7.119
#
#     Standard Error  Economy (GDP per Capita)_2015  Family_2015  \
# 14         0.03839                        1.39451      1.24711
#
#     Health (Life Expectancy)_2015  Freedom_2015  \
# 14                        0.86179       0.54604
#
#     Trust (Government Corruption)_2015  ...  Generosity_2018  \
# 14                              0.1589  ...            0.291
#
#     Trust (Government Corruption)_2018 Happiness Rank_2019  \
# 14                               0.133                19.0
#
#     Happiness Score_2019  Economy (GDP per Capita)_2019  Social support_2019  \
# 14                 6.892                          1.433                1.457
#
#     Health (Life Expectancy)_2019  Freedom_2019  Generosity_2019  \
# 14                          0.874         0.454             0.28
#
#     Trust (Government Corruption)_2019
# 14                               0.128
#
# [1 rows x 51 columns]

# %%
global_info = pd.read_csv("world-data-2023.csv")
global_info.head(3)
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
# 2      Algeria               18           DZ                17.40%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
# 2      2,381,741           317,000       24.28         213.0
#
#   Capital/Major City Co2-Emissions  ... Out of pocket health expenditure  \
# 0              Kabul         8,672  ...                           78.40%
# 1             Tirana         4,536  ...                           56.90%
# 2            Algiers       150,006  ...                           28.10%
#
#   Physicians per thousand  Population  \
# 0                    0.28  38,041,754
# 1                    1.20   2,854,191
# 2                    1.72  43,053,054
#
#    Population: Labor force participation (%) Tax revenue (%) Total tax rate  \
# 0                                     48.90%           9.30%         71.40%
# 1                                     55.70%          18.60%         36.60%
# 2                                     41.20%          37.20%         66.10%
#
#   Unemployment rate Urban_population   Latitude  Longitude
# 0            11.12%        9,797,273  33.939110  67.709953
# 1            12.33%        1,747,593  41.153332  20.168331
# 2            11.70%       31,510,100  28.033886   1.659626
#
# [3 rows x 35 columns]

# %%
sns.scatterplot(data = comb, x = '2015_NetMig',
                y = 'Muslims',
                hue = 'Country', legend = False)
for line in range(0, comb.shape[0]):
       plt.text(comb['2015_NetMig'][line] + 0.1, comb.Muslims[line], comb.Country[line],
                horizontalalignment='left', size='small', color='black')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1214491105.py in <cell line: 0>()
# ----> 1 sns.scatterplot(data = comb, x = '2015_NetMig',
#       2                 y = 'Muslims',
#       3                 hue = 'Country', legend = False)
#       4 for line in range(0, comb.shape[0]):
#       5        plt.text(comb['2015_NetMig'][line] + 0.1, comb.Muslims[line], comb.Country[line],
#
# NameError: name 'comb' is not defined

# %%
# "Cote D'Ivoire" --> "Ivory Coast"
net_mig.loc[net_mig['Country'] == "Cote d'Ivoire",'Country'] = "Ivory Coast"
# "Iran, Islamic Rep." --> "Iran"
net_mig.loc[net_mig['Country'] == "Iran, Islamic Rep.",'Country'] = "Iran"
#  "Korea, Dem. People's Rep." --> "North Korea"
net_mig.loc[net_mig['Country'] == "Korea, Dem. People's Rep.",'Country'] = "North Korea"
# "Korea, Rep." --> "South Korea"
net_mig.loc[net_mig['Country'] == "Korea, Rep.",'Country'] = "South Korea"
#  "Kyrgyz Republic" --> "Kyrgyzstan"
net_mig.loc[net_mig['Country'] == "Kyrgyz Republic",'Country'] = "Kyrgyzstan"
# "Lao PDR" --> "Laos"
net_mig.loc[net_mig['Country'] == "Lao PDR",'Country'] = "Laos"
# "North Macedonia" --> "Macedonia"
net_mig.loc[net_mig['Country'] == "North Macedonia",'Country'] = "Macedonia"
# "Russian Federation" --> "Russia"
net_mig.loc[net_mig['Country'] == "Russian Federation",'Country'] = "Russia"
# 'Slovak Republic' --> "Slovakia"
net_mig.loc[net_mig['Country'] == "Slovak Republic",'Country'] = "Slovakia"
# 'Eswatini' --> "Swaziland"
net_mig.loc[net_mig['Country'] == "Eswatini",'Country'] = "Swaziland"
#  'Syrian Arab Republic' --> "Syria"
net_mig.loc[net_mig['Country'] == "Syrian Arab Republic",'Country'] = "Syria"
# 'Turkiye' --> "Turkey"
net_mig.loc[net_mig['Country'] == "Turkiye",'Country'] = "Turkey"
# 'Venezuela, RB' --> "Venezuela"
net_mig.loc[net_mig['Country'] == "Venezuela, RB",'Country'] = "Venezuela"
# 'Viet Nam' --> "Vietnam"
net_mig.loc[net_mig['Country'] == "Viet Nam",'Country'] = "Vietnam"
# 'Yemen, Rep.' --> "Yemen"
net_mig.loc[net_mig['Country'] == "Yemen, Rep.",'Country'] = "Yemen"

# %%
# Congo (Brazzaville) --> 'Congo, Rep.'
happy_full.loc[happy_full['Country'] == "Congo (Brazzaville)",'Country'] = "Congo, Rep."
# "Congo (Kinshasa)" -->'Congo, Dem. Rep.'
happy_full.loc[happy_full['Country'] == "Congo (Kinshasa)",'Country'] = "Congo, Dem. Rep."
# "North Cyprus" --> "Cyprus"
happy_full.loc[happy_full['Country'] == "North Cyprus",'Country'] = "Cyprus"
# "Somaliland region" --> "Somalia"
happy_full.loc[happy_full['Country'] == "Somaliland region",'Country'] = "Somalia"

# %%
# Bahamas, The --> The Bahamas
net_mig.loc[net_mig['Country'] == "Bahamas, The",'Country'] = "The Bahamas"
# 'Brunei Darussalam' --> Brunei
net_mig.loc[net_mig['Country'] == "Brunei Darussalam",'Country'] = "Brunei"
# 'Cabo Verde' --> 'Cape Verde']
net_mig.loc[net_mig['Country'] == "Cabo Verde",'Country'] = "Cape Verde"
# 'Egypt, Arab Rep.' --> "Egypt"
net_mig.loc[net_mig['Country'] == "Egypt, Arab Rep.",'Country'] = "Egypt"
# 'Gambia, The' --> The Gambia
net_mig.loc[net_mig['Country'] == "Gambia, The",'Country'] = "The Gambia"
# Sum up net migration across data set
net_mig["NetMigSince1960"] = net_mig.iloc[:, 2:67].apply(sum, axis = 1)

# %%
list(global_info.sort_values('Country')['Country'])[186:205]
#  'Democratic Republic of the Congo' -- > 'Congo, Dem. Rep.'
global_info.loc[global_info['Country'] == "Democratic Republic of the Congo",
                'Country'] = "Congo, Dem. Rep."
# Republic of the Congo --> 'Congo, Rep.'
global_info.loc[global_info['Country'] == "Republic of the Congo",
                'Country'] = "Congo, Rep."
# Czech Republic --> 'Czechia'
global_info.loc[global_info['Country'] == "Czech Republic",
                'Country'] = "Czechia"
# East Timor --> Timor-Leste
global_info.loc[global_info['Country'] == "East Timor",
                'Country'] = "Timor-Leste"
# Eswatini --> Swaziland
global_info.loc[global_info['Country'] == "Eswatini",
                'Country'] = "Swaziland"
# Federated States of Micronesia --> Micronesia
global_info.loc[global_info['Country'] == "Federated States of Micronesia",
                'Country'] = "Micronesia"
# Ireland
global_info.loc[global_info['Country'] == "Republic of Ireland",
                'Country'] = "Ireland"
# Kosovo

# Macedonia
global_info.loc[global_info['Country'] == "North Macedonia",
                'Country'] = "Macedonia"
# 'Saint Kitts and Nevis'
global_info.loc[global_info['Country'] == "Saint Kitts and Nevis",
                'Country'] = "St. Kitts and Nevis"
# 'Saint Lucia'
global_info.loc[global_info['Country'] == "Saint Lucia",
                'Country'] = "St. Lucia"
# 'Saint Vincent and the Grenadines'
global_info.loc[global_info['Country'] == "Saint Vincent and the Grenadines",
                'Country'] = "St. Vincent and the Grenadines"
# S����������� --> Sao Tome and Principe
global_info.loc[global_info['Country'] == "S�����������",
                'Country'] = "Sao Tome and Principe"

# %%
global_info['Country'][70:90]

# %%
countries_df = global_info.merge(
    net_mig, on = "Country", how = "left").merge(
        rel_comp[rel_comp['Year'] == 2010], on = "Country", how = "left").merge(
                happy_full, on = "Country", how = "left")

countries_df.head(3)
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
# 2      Algeria               18           DZ                17.40%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
# 2      2,381,741           317,000       24.28         213.0
#
#   Capital/Major City Co2-Emissions  ... Generosity_2018  \
# 0              Kabul         8,672  ...           0.191
# 1             Tirana         4,536  ...           0.149
# 2            Algiers       150,006  ...           0.055
#
#   Trust (Government Corruption)_2018 Happiness Rank_2019  \
# 0                              0.036               154.0
# 1                              0.032               107.0
# 2                              0.135                88.0
#
#    Happiness Score_2019 Economy (GDP per Capita)_2019 Social support_2019  \
# 0                 3.203                         0.350               0.517
# 1                 4.719                         0.947               0.848
# 2                 5.211                         1.002               1.160
#
#   Health (Life Expectancy)_2019 Freedom_2019 Generosity_2019  \
# 0                         0.361        0.000           0.158
# 1                         0.874        0.383           0.178
# 2                         0.785        0.086           0.073
#
#    Trust (Government Corruption)_2019
# 0                               0.025
# 1                               0.027
# 2                               0.114
#
# [3 rows x 164 columns]

# %%
countries_df_subset = countries_df[['Country', 'Density\n(P/Km2)',
 'Agricultural Land( %)', 'Land Area(Km2)','Armed Forces size','Birth Rate',
 'Calling Code','Capital/Major City','Co2-Emissions','CPI','CPI Change (%)',
 'Currency-Code','Fertility Rate','Forested Area (%)','Gasoline Price',
 'GDP','Gross primary education enrollment (%)','Gross tertiary education enrollment (%)',
 'Infant mortality','Largest city','Life expectancy','Maternal mortality ratio',
 'Minimum wage','Out of pocket health expenditure','Physicians per thousand',
 'Population_x','Population: Labor force participation (%)','Tax revenue (%)',
 'Total tax rate','Unemployment rate','Urban_population','Latitude','Longitude',
 '1960_NetMig','1970_NetMig','1980_NetMig','1990_NetMig','2000_NetMig',
 '2010_NetMig','2020_NetMig','Population_y','Christians','Muslims',
 'Religiously_unaffiliated','Buddhists','Hindus','Jews','Other_religions',
 'Happiness Rank_2015','Happiness Score_2015','Standard Error',
 'Economy (GDP per Capita)_2015','Family_2015','Health (Life Expectancy)_2015',
 'Freedom_2015','Trust (Government Corruption)_2015','Generosity_2015',
 'Dystopia Residual_2015','Happiness Rank_2019','Happiness Score_2019',
 'Economy (GDP per Capita)_2019','Social support_2019','Health (Life Expectancy)_2019',
 'Freedom_2019','Generosity_2019','Trust (Government Corruption)_2019']]

# %%
countries_df_subset.rename(columns = {'Population_x':'Population_2023', 'Population_y':'Population_2010'}, inplace = True)
# Out:
# /tmp/ipython-input-3766902817.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   countries_df_subset.rename(columns = {'Population_x':'Population_2023', 'Population_y':'Population_2010'}, inplace = True)

# %%
def strnum_to_int(x):
  y = "".join(x.split(","))
  return(y)

#countries_df_subset['Population_2023'].apply(strnum_to_int)

# Check types that are float
for i in range(len(countries_df_subset['Population_2023'])):
  row = countries_df_subset['Population_2023'][i]
  row_type = type(row)
  if(isinstance(row, float)):
    print(i, row_type)

# Drop Palestinian National Authority
countries_df_subset.drop(134, inplace = True)
# Out:
# 134 <class 'float'>
# /tmp/ipython-input-3590105275.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   countries_df_subset.drop(134, inplace = True)

# %%
countries_df_subset.loc[:, 'Population_2023'] = countries_df_subset['Population_2023'].apply(strnum_to_int)

# %%
countries_df_subset[['Population_2010', 'Population_2023']]
# Out:
#      Population_2010 Population_2023
# 0         28284088.5        38041754
# 1          2928721.5         2854191
# 2         36188235.5        43053054
# 3                NaN           77142
# 4         23294825.0        31825295
# ..               ...             ...
# 191       28813101.0        28515829
# 192       87455151.5        96462106
# 193       26754387.0        29161922
# 194       13965594.0        17861030
# 195       13356547.5        14645468
#
# [195 rows x 2 columns]

# %%
countries_df_subset.reset_index(inplace=True)

# %%
countries_df_subset.loc[:,'Population_2023'] = countries_df_subset['Population_2023'].apply(int)

# %%
sns.scatterplot(data = countries_df_subset, x = "Population_2010", y = "Population_2023", hue = "Country", legend = False)
for line in range(0, countries_df_subset.shape[0]):
       plt.text(countries_df_subset['Population_2010'][line] + 0.1, countries_df_subset.Population_2023[line], countries_df_subset.Country[line],
                horizontalalignment='left', fontsize=6, color='black')

# plt.axline(x=5, color='red', linestyle='--', label='Vertical Line')

plt.axline(xy1 = (0.0, 0.0), linestyle = ":", slope = 1)
plt.figure(figsize=(25, 10))

# %%
sns.scatterplot(data = comb, x = '2015_NetMig',
                y = 'Economy (GDP per Capita)_2015',
                hue = 'Country', legend = False)

comb.columns
sns.scatterplot(data = comb, x = '2015_NetMig',
                y = 'Christians',
                hue = 'Country', legend = False)
for line in range(0, comb.shape[0]):
       plt.text(comb['2015_NetMig'][line] + 0.1, comb.Christians[line], comb.Country[line],
                horizontalalignment='left', size='small', color='black')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3298591619.py in <cell line: 0>()
# ----> 1 sns.scatterplot(data = comb, x = '2015_NetMig',
#       2                 y = 'Economy (GDP per Capita)_2015',
#       3                 hue = 'Country', legend = False)
#       4
#       5 comb.columns
#
# NameError: name 'comb' is not defined

# %%
lplt = sns.lineplot(data=net_mig_long, x = 'Year', y='netMig',
             hue='Country Name', legend = False)
#plt.setp(lplt.get_legend().get_texts(), fontsize='2') # for legend text
plt.show()

# %%
sns.lineplot(data= net_mig_long[net_mig_long['Country Name'] == 'United States'], x = 'Year', y='netMig',
             hue='Country Name', legend = False)
# Out:
# <Axes: xlabel='Year', ylabel='netMig'>

# %%
countries_df_subset[['Density\n(P/Km2)','Agricultural Land( %)','Land Area(Km2)','Armed Forces size','Birth Rate', 'Co2-Emissions','CPI',
                     'CPI Change (%)','Currency-Code','Fertility Rate','Forested Area (%)','Gasoline Price','GDP','Gross primary education enrollment (%)',
                     'Gross tertiary education enrollment (%)','Infant mortality', 'Life expectancy','Maternal mortality ratio','Minimum wage',
                     'Out of pocket health expenditure','Physicians per thousand','Population_2023','Population: Labor force participation (%)',
                     'Tax revenue (%)','Total tax rate','Unemployment rate','Urban_population','Latitude','Longitude','1960_NetMig','1970_NetMig',
                     '1980_NetMig','1990_NetMig','2000_NetMig','2010_NetMig','2020_NetMig','Population_2010','Christians','Muslims',
                     'Religiously_unaffiliated','Buddhists','Hindus','Jews','Other_religions','Happiness Rank_2015','Happiness Score_2015',
                     'Standard Error','Economy (GDP per Capita)_2015','Family_2015','Health (Life Expectancy)_2015','Freedom_2015',
                     'Trust (Government Corruption)_2015','Generosity_2015','Dystopia Residual_2015','Happiness Rank_2019','Happiness Score_2019',
                     'Economy (GDP per Capita)_2019','Social support_2019','Health (Life Expectancy)_2019','Freedom_2019','Generosity_2019',
                     'Trust (Government Corruption)_2019']]

# %%
sns.pairplot(countries_df_subset[['Density\n(P/Km2)','Agricultural Land( %)','Land Area(Km2)','Armed Forces size','Birth Rate', 'Co2-Emissions','CPI',
                     'CPI Change (%)','Currency-Code','Fertility Rate','Forested Area (%)','Gasoline Price','GDP','Gross primary education enrollment (%)',
                     'Gross tertiary education enrollment (%)','Infant mortality', 'Life expectancy', '1990_NetMig','2000_NetMig','2010_NetMig','2020_NetMig']])

sns.pairplot(countries_df_subset[['Maternal mortality ratio','Minimum wage',
                     'Out of pocket health expenditure','Physicians per thousand','Population_2023','Population: Labor force participation (%)',
                     'Tax revenue (%)','Total tax rate','Unemployment rate','Urban_population','Latitude','Longitude','1960_NetMig','1970_NetMig',
                     '1980_NetMig','1990_NetMig','2000_NetMig','2010_NetMig','2020_NetMig']])

sns.pairplot(countries_df_subset[['2020_NetMig','Population_2010','Christians','Muslims',
                     'Religiously_unaffiliated','Buddhists','Hindus','Jews','Other_religions','Happiness Score_2015',
                     'Standard Error','Family_2015','Health (Life Expectancy)_2015','Freedom_2015',
                     'Trust (Government Corruption)_2015','Generosity_2015','Dystopia Residual_2015','Happiness Score_2019',
                     'Social support_2019','Health (Life Expectancy)_2019','Freedom_2019','Generosity_2019',
                     'Trust (Government Corruption)_2019']])
# Out:
# Error in callback <function _draw_all_if_interactive at 0x7caafdcd6660> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in _draw_all_if_interactive()
#     277 def _draw_all_if_interactive() -> None:
#     278     if matplotlib.is_interactive():
# --> 279         draw_all()
#     280
#     281
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     129         for manager in cls.get_all_fig_managers():
#     130             if force or manager.canvas.figure.stale:
# --> 131                 manager.canvas.draw_idle()
#     132
#     133
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1889         if not self._is_idle_drawing:
#    1890             with self._idle_draw_cntx():
# -> 1891                 self.draw(*args, **kwargs)
#    1892
#    1893     @property
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     380         with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     381               else nullcontext()):
# --> 382             self.figure.draw(self.renderer)
#     383             # A GUI class may be need to update a window using this draw, so
#     384             # don't forget to call the superclass.
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      92     @wraps(draw)
#      93     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94         result = draw(artist, renderer, *args, **kwargs)
#      95         if renderer._rasterizing:
#      96             renderer.stop_rasterizing()
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    3255
#    3256                 self.patch.draw(renderer)
# -> 3257                 mimage._draw_list_compositing_images(
#    3258                     renderer, self, artists, self.suppressComposite)
#    3259
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132     if not_composite or not has_images:
#     133         for a in artists:
# --> 134             a.draw(renderer)
#     135     else:
#     136         # Composite any adjacent images together
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3179             _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
#    3180
# -> 3181         mimage._draw_list_compositing_images(
#    3182             renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3183
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132     if not_composite or not has_images:
#     133         for a in artists:
# --> 134             a.draw(renderer)
#     135     else:
#     136         # Composite any adjacent images together
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axis.py in draw(self, renderer)
#    1420
#    1421         # Shift label away from axes to avoid overlapping ticklabels.
# -> 1422         self._update_label_position(renderer)
#    1423         self.label.draw(renderer)
#    1424
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axis.py in _update_label_position(self, renderer)
#    2457         # get bounding boxes for this axis and any siblings
#    2458         # that have been set by `fig.align_xlabels()`
# -> 2459         bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2460         x, y = self.label.get_position()
#    2461
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axis.py in _get_tick_boxes_siblings(self, renderer)
#    2249         for ax in grouper.get_siblings(self.axes):
#    2250             axis = ax._axis_map[name]
# -> 2251             ticks_to_draw = axis._update_ticks()
#    2252             tlb, tlb2 = axis._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    2253             bboxes.extend(tlb)
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axis.py in _update_ticks(self)
#    1297             tick.label1.set_text(label)
#    1298             tick.label2.set_text(label)
# -> 1299         minor_locs = self.get_minorticklocs()
#    1300         minor_labels = self.minor.formatter.format_ticks(minor_locs)
#    1301         minor_ticks = self.get_minor_ticks(len(minor_locs))
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axis.py in get_minorticklocs(self)
#    1549             # rtol for np.isclose.
#    1550             tol = (hi - lo) * 1e-5
# -> 1551             mask = np.isclose(tr_minor_locs[:, None], tr_major_locs[None, :],
#    1552                               atol=tol, rtol=0).any(axis=1)
#    1553             minor_locs = minor_locs[~mask]
#
# /usr/local/lib/python3.11/dist-packages/numpy/_core/numeric.py in isclose(a, b, rtol, atol, equal_nan)
#    2415
#    2416     with errstate(invalid='ignore'), _no_nep50_warning():
# -> 2417         result = (less_equal(abs(x-y), atol + rtol * abs(y))
#    2418                   & isfinite(y)
#    2419                   | (x == y))
#
# KeyboardInterrupt:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Error in callback <function flush_figures at 0x7caafdcd42c0> (for post_execute):
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/events.py", line 89, in trigger
#     func(*args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/matplotlib_inline/backend_inline.py", line 126, in flush_figures
#     return show(True)
#            ^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/matplotlib_inline/backend_inline.py", line 90, in show
#     display(
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/display.py", line 320, in display
#     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py", line 180, in format
#     data = formatter(obj)
#            ^^^^^^^^^^^^^^
#   File "<decorator-gen-2>", line 2, in __call__
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py", line 224, in catch_format_error
#     r = method(self, *args, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py", line 341, in __call__
#     return printer(obj)
#            ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py", line 151, in print_figure
#     fig.canvas.print_figure(bytes_io, **kw)
#   File "/usr/local/lib/python3.11/dist-packages/matplotlib/backend_bases.py", line 2184, in print_figure
#     result = print_method(
#              ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/matplotlib/backend_bases.py", line 2040, in <lambda>
#     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#                                                                  ^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/matplotlib/backends/backend_agg.py", line 481, in print_png
#     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#   File "/usr/local/lib/python3.11/dist-packages/matplotlib/backends/backend_agg.py", line 429, in _print_pil
#     FigureCanvasAgg.draw(self)
#   File "/usr/local/lib/python3.11/dist-packages/matplotlib/backends/backend_agg.py", line 382, in draw
#     self.figure.draw(self.renderer)
#   File "/usr/local/lib/python3.11/dist-packages/matplotlib/artist.py", line 94, in draw_wrapper
#     result = draw(artist, renderer, *args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/matplotlib/artist.py", line 71, in draw_wrapper
#     return draw(artist, renderer)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/matplotlib/figure.py", line 3257, in draw
#     mimage._draw_list_compositing_images(
#   File "/usr/local/lib/python3.11/dist-packages/matplotlib/image.py", line 134, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "/usr/local/lib/python3.11/dist-packages/matplotlib/artist.py", line 71, in draw_wrapper
#     return draw(artist, renderer)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/matplotlib/axes/_base.py", line 3181, in draw
#     mimage._draw_list_compositing_images(
#   File "/usr/local/lib/python3.11/dist-packages/matplotlib/image.py", line 134, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "/usr/local/lib/python3.11/dist-packages/matplotlib/artist.py", line 71, in draw_wrapper
#     return draw(artist, renderer)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/matplotlib/axis.py", line 1422, in draw
#     self._update_label_position(renderer)
#   File "/usr/local/lib/python3.11/dist-packages/matplotlib/axis.py", line 2465, in _update_label_position
#     *bboxes, self.axes.spines.get("bottom", self.axes).get_window_extent()])
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/matplotlib/spines.py", line 158, in get_window_extent
#     drawn_ticks = self.axis._update_ticks()
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/matplotlib/axis.py", line None, in _update_ticks
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1739, in getinnerframes
#     traceback_info = getframeinfo(tb, context)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1686, in getframeinfo
#     start = lineno - 1 - context//2
#             ~~~~~~~^~~
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'int'

# %%
sns.pairplot(countries_df_subset[['Density\n(P/Km2)','Agricultural Land( %)','Land Area(Km2)','Armed Forces size','Birth Rate', 'Co2-Emissions','CPI',
                     'CPI Change (%)','Fertility Rate','Forested Area (%)','Gasoline Price','GDP','Gross primary education enrollment (%)',
                     'Gross tertiary education enrollment (%)','Infant mortality', 'Life expectancy', '1990_NetMig','2000_NetMig','2010_NetMig','2020_NetMig',
                      'Christians','Muslims','Religiously_unaffiliated','Buddhists','Hindus','Jews']])

# %%
sns.scatterplot(data = countries_df_subset, x = '2010_NetMig',
                y = 'Muslims',
                hue = 'Country', legend = False)
for line in range(0, countries_df_subset.shape[0]):
       plt.text(countries_df_subset['2010_NetMig'][line] + 0.1, countries_df_subset.Muslims[line], countries_df_subset.Country[line],
                horizontalalignment='left', size='small', color='black')
plt.show()

countries_df_subset.columns

# %%
sns.scatterplot(data = countries_df, x = 'NetMigSince1960',
                y = 'Christians',
                hue = 'Country', legend = False)
for line in range(0, countries_df.shape[0]):
       plt.text(countries_df['NetMigSince1960'][line] + 0.1, countries_df.Christians[line], countries_df.Country[line],
                horizontalalignment='left', size='small', color='black')
plt.xlim(-1e7,2e7)
plt.show()

# %%
sns.scatterplot(data = countries_df, x = 'NetMigSince1960',
                y = 'Muslims',
                hue = 'Country', legend = False)
for line in range(0, countries_df.shape[0]):
       plt.text(countries_df['NetMigSince1960'][line] + 0.1, countries_df.Muslims[line], countries_df.Country[line],
                horizontalalignment='left', size='small', color='black')
plt.show()

# %%
sns.scatterplot(data = countries_df, x = 'NetMigSince1960',
                y = 'Religiously_unaffiliated',
                hue = 'Country', legend = False)
for line in range(0, countries_df.shape[0]):
       plt.text(countries_df['NetMigSince1960'][line] + 0.1, countries_df.Muslims[line], countries_df.Country[line],
                horizontalalignment='left', size='small', color='black')
plt.show()

# %%
sns.scatterplot(data = countries_df, x = 'Muslims',
                y = 'Trust (Government Corruption)_2015',
                hue = 'Country', legend = False)
for line in range(0, countries_df.shape[0]):
       plt.text(countries_df.Muslims[line] + 0.1,
                countries_df['Trust (Government Corruption)_2015'][line], countries_df.Country[line],
                horizontalalignment='left', size='small', color='black')
plt.show()

sns.scatterplot(data = countries_df, x = 'Christians',
                y = 'Trust (Government Corruption)_2015',
                hue = 'Country', legend = False)
for line in range(0, countries_df.shape[0]):
       plt.text(countries_df.Christians[line] + 0.1,
                countries_df['Trust (Government Corruption)_2015'][line], countries_df.Country[line],
                horizontalalignment='left', size='small', color='black')
plt.show()

sns.scatterplot(data = countries_df, x = 'Christians',
                y = 'Happiness Score_2015',
                hue = 'Country', legend = False)
for line in range(0, countries_df.shape[0]):
       plt.text(countries_df.Christians[line] + 0.1,
                countries_df['Happiness Score_2015'][line], countries_df.Country[line],
                horizontalalignment='left', size='small', color='black')
plt.show()

sns.scatterplot(data = countries_df, x = 'Muslims',
                y = 'Happiness Score_2015',
                hue = 'Country', legend = False)
for line in range(0, countries_df.shape[0]):
       plt.text(countries_df.Muslims[line] + 0.1,
                countries_df['Happiness Score_2015'][line], countries_df.Country[line],
                horizontalalignment='left', size='small', color='black')
plt.show()

sns.scatterplot(data = countries_df, x = 'NetMigSince1960',
                y = 'Happiness Score_2015',
                hue = 'Country', legend = False)
for line in range(0, countries_df.shape[0]):
       plt.text(countries_df.Muslims[line] + 0.1,
                countries_df.NetMigSince1960[line], countries_df.Country[line],
                horizontalalignment='left', size='small', color='black')
plt.show()
