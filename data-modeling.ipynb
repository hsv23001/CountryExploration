# %%
import pandas as pd
import numpy as np

from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression

countries_nona = pd.read_csv("test_model_df.csv")

# %%
countries_nona.columns[36]
X = countries_nona.drop(countries_nona.columns[36], axis = 1)

# ['Country', 'Abbreviation', 'Capital/Major City', 'Largest city', 'Official language', 'Country Code', 'Region', 'Level', 'Countrycode', 'Region_2015', 'Standard Error', ]

# %%
X = X.drop(X.columns[48:91], axis = 1)

# %%
X = X.drop(['Country', 'Abbreviation', 'Capital/Major City', 'Largest city', 'Official language', 'Country Code', 'Region', 'Level', 'Countrycode'], axis = 1)

# %%
X = X.drop(['Currency-Code'], axis = 1)

# %%
X.describe(include = "all")
# Out:
#        Density\n(P/Km2) Agricultural Land( %) Land Area(Km2)  \
# count                95                    95             95
# unique               78                    90             95
# top                  83                64.80%        652,230
# freq                  3                     2              1
# mean                NaN                   NaN            NaN
# std                 NaN                   NaN            NaN
# min                 NaN                   NaN            NaN
# 25%                 NaN                   NaN            NaN
# 50%                 NaN                   NaN            NaN
# 75%                 NaN                   NaN            NaN
# max                 NaN                   NaN            NaN
#
#        Armed Forces size  Birth Rate  Calling Code Co2-Emissions         CPI  \
# count                 95   95.000000     95.000000            95   95.000000
# ...

# %%
def strnum_to_int(x):
  y = "".join(x.split(","))
  return(y)

X.loc[:, 'Density\n(P/Km2)'] = X['Density\n(P/Km2)'].apply(strnum_to_int)
X.loc[:, 'Land Area(Km2)'] = X['Land Area(Km2)'].apply(strnum_to_int)
X.loc[:, 'Armed Forces size'] = X['Armed Forces size'].apply(strnum_to_int)
X.loc[:, 'Co2-Emissions'] = X['Co2-Emissions'].apply(strnum_to_int)

# %%
X.describe(include = 'all')
# Out:
#        Density\n(P/Km2) Agricultural Land( %) Land Area(Km2)  \
# count                95                    95             95
# unique               78                    90             95
# top                  83                64.80%         652230
# freq                  3                     2              1
# mean                NaN                   NaN            NaN
# std                 NaN                   NaN            NaN
# min                 NaN                   NaN            NaN
# 25%                 NaN                   NaN            NaN
# 50%                 NaN                   NaN            NaN
# 75%                 NaN                   NaN            NaN
# max                 NaN                   NaN            NaN
#
#        Armed Forces size  Birth Rate  Calling Code Co2-Emissions         CPI  \
# count                 95   95.000000     95.000000            95   95.000000
# ...

# %%
X.dropna(how = "all").shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 X.dropna(how = "all").shape()
#
# TypeError: 'tuple' object is not callable

# %%
y = countries_nona[["NetMigSince1960"]]
y.head()
# Out:
#    NetMigSince1960
# 0       -5046170.0
# 1       -1475018.0
# 2        -212779.0
# 3         514109.0
# 4        -881928.0

# %%
X_num = X.select_dtypes(include = np.number)

# %%
lm_model = LinearRegression()
lm_model.fit(X_num, y)
y_pred = lm_model.predict(X_num)

# %%
r2_score(y, y_pred)
# Out:
# 0.40299243769280824

# %%
lm_model.coef_
names_list = list(X_num.columns)
coef_list = lm_model.coef_

list(coef_list)
lm_coef = pd.DataFrame({'names': list(X_num.columns), 'coef': lm_model.coef_.ravel().tolist()})

lm_coef
# Out:
#                                  names          coef
# 0                           Birth Rate  1.971762e+05
# 1                         Calling Code -2.688234e+03
# 2                                  CPI -5.577604e+02
# 3                       Fertility Rate  2.017500e+06
# 4                     Infant mortality -3.552393e+05
# 5                      Life expectancy -6.206414e+05
# 6             Maternal mortality ratio  8.544528e+03
# 7              Physicians per thousand  1.111257e+06
# 8                             Latitude  9.044981e+03
# 9                            Longitude -5.749865e+04
# 10                                Year  1.635918e+04
# 11                        Population_y -5.020348e-03
# 12                          Christians -3.840100e+11
# 13                             Muslims -3.840100e+11
# 14            Religiously_unaffiliated -3.840099e+11
# 15                           Buddhists -3.840100e+11
# 16                              Hindus -3.840100e+11
# ...

# %%
lm_model.rank_
# Out:
# 25

# %%
X.describe(include = 'all')
# Out:
#        Density\n(P/Km2) Agricultural Land( %) Land Area(Km2)  \
# count                95                    95             95
# unique               78                    90             95
# top                  83                64.80%         652230
# freq                  3                     2              1
# mean                NaN                   NaN            NaN
# std                 NaN                   NaN            NaN
# min                 NaN                   NaN            NaN
# 25%                 NaN                   NaN            NaN
# 50%                 NaN                   NaN            NaN
# 75%                 NaN                   NaN            NaN
# max                 NaN                   NaN            NaN
#
#        Armed Forces size  Birth Rate  Calling Code Co2-Emissions         CPI  \
# count                 95   95.000000     95.000000            95   95.000000
# ...
